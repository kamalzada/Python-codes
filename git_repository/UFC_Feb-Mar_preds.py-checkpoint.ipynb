# %% [markdown]
# We'll be predicting the results of the following upcoming fights:

# %% [markdown]
# Israel Adesanya vs Robert Whittaker 2 (Middleweight)

# %% [markdown]
# Alexander Volkanovski vs Chan Sung Jung (Featherweight)

# %% [markdown]
# Islam Makhachev vs Beneil Dariush (Lightweight)

# %% [markdown]
# Aljamain Sterling vs Petr Yan (Bantamweight)

# %%
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('gruvboxd')
# Out:
# <style> div#notebook {
#  font-family: sans-serif;
#  font-size: 13pt;
#  line-height: 170%;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
#  padding-top: 25px !important;
# }
# body,
# div.body {
#  font-family: sans-serif;
#  font-size: 13pt;
#  color: #ebdbb2;
#  background-color: #1d2021;
#  background: #1d2021;
#  -webkit-font-smoothing: antialiased !important;
# }
# body.notebook_app {
#  padding: 0;
#  background-color: #1d2021;
#  background: #1d2021;
#  padding-right: 0px !important;
#  overflow-y: hidden;
# }
# a {
#  font-family: sans-serif;
#  color: #ebdbb2;
#  -webkit-font-smoothing: antialiased !important;
# }
# a:hover,
# a:focus {
#  color: #fbf1c7;
#  -webkit-font-smoothing: antialiased !important;
# }
# div#maintoolbar {
#  position: absolute;
#  width: 90%;
#  margin-left: -10%;
#  padding-right: 8%;
#  float: left;
#  background: transparent !important;
# }
# #maintoolbar {
#  margin-bottom: -3px;
#  margin-top: 0px;
#  border: 0px;
#  min-height: 27px;
#  padding-top: 2px;
#  padding-bottom: 0px;
# }
# #maintoolbar .container {
#  width: 75%;
#  margin-right: auto;
#  margin-left: auto;
# }
# .list_header,
# div#notebook_list_header.row.list_header {
#  font-size: 14pt;
#  color: #fbf1c7;
#  background-color: transparent;
#  height: 35px;
# }
# i.fa.fa-folder {
#  display: inline-block;
#  font: normal normal normal 14px "FontAwesome";
#  font-family: "FontAwesome" !important;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  font-size: 18px;
#  -moz-osx-font-smoothing: grayscale;
# }
# #running .panel-group .panel .panel-heading {
#  font-size: 14pt;
#  color: #ebdbb2;
#  padding: 8px 8px;
#  background: #1b1d1e;
#  background-color: #1b1d1e;
# }
# #running .panel-group .panel .panel-heading a {
#  font-size: 14pt;
#  color: #ebdbb2;
# }
# #running .panel-group .panel .panel-heading a:focus,
# #running .panel-group .panel .panel-heading a:hover {
#  font-size: 14pt;
#  color: #ebdbb2;
# }
# #running .panel-group .panel .panel-body .list_container .list_item {
#  background: #282828;
#  background-color: #282828;
#  padding: 2px;
#  border-bottom: 2px solid rgba(70,70,70,.5);
# }
# #running .panel-group .panel .panel-body .list_container .list_item:hover {
#  background: #282828;
#  background-color: #282828;
# }
# #running .panel-group .panel .panel-body {
#  padding: 2px;
# }
# button#refresh_running_list {
#  border: none !important;
# }
# button#refresh_cluster_list {
#  border: none !important;
# }
# div.running_list_info.toolbar_info {
#  font-size: 15px;
#  padding: 4px 0 4px 0;
#  margin-top: 5px;
#  margin-bottom: 8px;
#  height: 24px;
#  line-height: 24px;
#  text-shadow: none;
# }
# .list_placeholder {
#  font-weight: normal;
# }
# #tree-selector {
#  padding: 0px;
#  border-color: transparent;
# }
# #project_name > ul > li > a > i.fa.fa-home {
#  color: #d5c4a1;
#  font-size: 17pt;
#  display: inline-block;
#  position: static;
#  padding: 0px 0px;
#  font-weight: normal;
#  text-align: center;
#  vertical-align: text-top;
# }
# .fa-folder:before {
#  color: #83a598;
# }
# .fa-arrow-up:before {
#  font-size: 14px;
# }
# .fa-arrow-down:before {
#  font-size: 14px;
# }
# span#last-modified.btn.btn-xs.btn-default.sort-action:hover .fa,
# span#sort-name.btn.btn-xs.btn-default.sort-action:hover .fa {
#  color: #fe8019;
# }
# .folder_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f07b";
#  color: #83a598;
# }
# .notebook_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f02d";
#  position: relative;
#  color: #b8bb26 !important;
#  top: 0px;
# }
# .file_icon:before {
#  display: inline-block;
#  font: normal normal normal 14px/1 FontAwesome;
#  font-size: inherit;
#  text-rendering: auto;
#  -webkit-font-smoothing: antialiased;
#  -moz-osx-font-smoothing: grayscale;
#  content: "\f15b";
#  position: relative;
#  top: 0px;
#  color: #d5c4a1 !important;
# }
# #project_name a {
#  display: inline-flex;
#  padding-left: 7px;
#  margin-left: -2px;
#  text-align: -webkit-auto;
#  vertical-align: baseline;
#  font-size: 18px;
# }
# div#notebook_toolbar div.dynamic-instructions {
#  font-family: sans-serif;
#  font-size: 17px;
#  color: #3c3836;
# }
# span#login_widget > .button,
# #logout {
#  font-family: "Proxima Nova", sans-serif;
#  color: #d5c4a1;
#  background: transparent;
#  background-color: transparent;
#  border: 2px solid rgba(70,70,70,.5);
#  font-weight: normal;
#  box-shadow: none;
#  text-shadow: none;
#  border-radius: 3px;
#  margin-right: 10px;
#  padding: 2px 7px;
# }
# span#login_widget > .button:hover,
# #logout:hover {
#  color: #fe8019;
#  background-color: transparent;
#  background: transparent;
#  border: 2px solid #fe8019;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 3px;
# }
# span#login_widget > .button:focus,
# #logout:focus,
# span#login_widget > .button.focus,
# #logout.focus,
# span#login_widget > .button:active,
# #logout:active,
# span#login_widget > .button.active,
# #logout.active,
# .open > .dropdown-togglespan#login_widget > .button,
# .open > .dropdown-toggle#logout {
#  color: #83a598;
#  background-color: #d5c4a1;
#  background: #d5c4a1;
#  border-color: #d5c4a1;
#  background-image: none;
#  box-shadow: none !important;
#  border-radius: 2px;
# }
# body > #header #header-container {
#  padding-bottom: 0px;
#  padding-top: 4px;
#  box-sizing: border-box;
#  -moz-box-sizing: border-box;
#  -webkit-box-sizing: border-box;
# }
# body > #header {
#  background: #1d2021;
#  background-color: #1d2021;
#  position: relative;
#  z-index: 100;
# }
# .list_container {
#  font-size: 13pt;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
# }
# .list_container > div {
#  border-bottom: 1px solid rgba(70,70,70,.4);
#  font-size: 13pt;
# }
# .list_header > div,
# .list_item > div {
#  padding-top: 6px;
#  padding-bottom: 2px;
#  padding-left: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 22px;
#  font-size: 13pt;
# }
# .item_icon {
#  color: #83a598;
#  font-size: 13pt;
#  vertical-align: middle;
# }
# .list_item input:not([type="checkbox"]) {
#  padding-right: 0px;
#  height: 1.75em;
#  width: 25%;
#  margin: 0px 0 0;
#  margin-top: 0px;
# }
# .list_header > div .item_link,
# .list_item > div .item_link {
#  margin-left: -1px;
#  vertical-align: middle;
#  line-height: 1.5em;
#  font-size: 12pt;
#  display: inline-table;
#  position: static;
# }
# #button-select-all {
#  height: 34px;
#  min-width: 55px;
#  z-index: 0;
#  border: none !important;
#  padding-top: 0px;
#  padding-bottom: 0px;
#  margin-bottom: 0px;
#  margin-top: 0px;
#  left: -3px;
#  border-radius: 0px !important;
# }
# #button-select-all:focus,
# #button-select-all:active:focus,
# #button-select-all.active:focus,
# #button-select-all.focus,
# #button-select-all:active.focus,
# #button-select-all.active.focus {
#  background-color: rgba(70,70,70,.5) !important;
#  background: rgba(70,70,70,.5) !important;
# }
# button#tree-selector-btn {
#  height: 34px;
#  font-size: 12.0pt;
#  border: none;
#  left: 0px;
#  border-radius: 0px !important;
# }
# input#select-all.pull-left.tree-selector {
#  margin-left: 7px;
#  margin-right: 2px;
#  margin-top: 2px;
#  top: 4px;
# }
# input[type="radio"],
# input[type="checkbox"] {
#  margin-top: 1px;
#  line-height: normal;
# }
# .delete-button {
#  border: none !important;
# }
# i.fa.fa-trash {
#  font-size: 13.5pt;
# }
# .list_container a {
#  font-size: 16px;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
#  font-weight: normal;
#  font-style: normal;
# }
# div.list_container a:hover {
#  color: #fbf1c7;
# }
# .list_header > div input,
# .list_item > div input {
#  margin-right: 7px;
#  margin-left: 12px;
#  vertical-align: baseline;
#  line-height: 22px;
#  position: relative;
#  top: -1px;
# }
# div.list_item:hover {
#  background-color: rgba(70,70,70,.2);
# }
# .breadcrumb > li {
#  font-size: 12.0pt;
#  color: #ebdbb2;
#  border: none;
#  text-shadow: none !important;
# }
# .breadcrumb > li + li:before {
#  content: "/\00a0";
#  padding: 0px;
#  color: #ebdbb2;
#  font-size: 18px;
# }
# #project_name > .breadcrumb {
#  padding: 0px;
#  margin-bottom: 0px;
#  background-color: transparent;
#  font-weight: normal;
#  margin-top: -2px;
# }
# ul#tabs a {
#  font-family: sans-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import plotly.express as px
import seaborn as sns 

from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import classification_report, roc_curve
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

from collections import Counter
from imblearn.over_sampling import ADASYN
from warnings import filterwarnings
from scipy.stats import zscore
import pickle
# %matplotlib inline

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
sns.set(style = 'darkgrid', palette = 'bright')
pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (12, 8)
filterwarnings(action = 'ignore')
# %matplotlib inline

# %%
raw = pd.concat(map(pd.read_csv, ['ufc-master.csv'])) 
df = raw.copy()

# %%
display(df.head(), df.describe(), df.shape)
# Out:
#              R_fighter        B_fighter  R_odds  B_odds        R_ev  \
# 0        Thiago Santos    Johnny Walker  -150.0     130   66.666667
# 1        Alex Oliveira       Niko Price   170.0    -200  170.000000
# 2       Misha Cirkunov  Krzysztof Jotko   110.0    -130  110.000000
# 3  Alexander Hernandez     Mike Breeden  -675.0     475   14.814815
# 4          Joe Solecki     Jared Gordon  -135.0     115   74.074074
#
#          B_ev        date                location country Winner  title_bout  \
# 0  130.000000  2021-10-02  Las Vegas, Nevada, USA     USA    Red       False
# 1   50.000000  2021-10-02  Las Vegas, Nevada, USA     USA   Blue       False
# 2   76.923077  2021-10-02  Las Vegas, Nevada, USA     USA   Blue       False
# 3  475.000000  2021-10-02  Las Vegas, Nevada, USA     USA    Red       False
# 4  115.000000  2021-10-02  Las Vegas, Nevada, USA     USA   Blue       False
#
#         weight_class gender  no_of_rounds  B_current_lose_streak  \
# 0  Light Heavyweight   MALE             5                      0
# 1       Welterweight   MALE             3                      2
# 2       Middleweight   MALE             3                      1
# 3        Lightweight   MALE             3                      1
# 4        Lightweight   MALE             3                      0
#
#    B_current_win_streak  B_draw  B_avg_SIG_STR_landed  B_avg_SIG_STR_pct  \
# 0                     1       0                  3.42               0.59
# 1                     0       0                  5.16               0.42
# 2                     0       0                  2.92               0.41
# 3                     0       0                  4.04               0.34
# 4                     2       0                  5.22               0.56
#
#    B_avg_SUB_ATT  B_avg_TD_landed  B_avg_TD_pct  B_longest_win_streak  \
# 0            0.7             0.24          1.00                     4
# 1            0.8             0.79          0.22                     2
# 2            0.1             1.15          0.34                     5
# 3            0.0             0.00          0.00                     0
# 4            0.0             2.54          0.39                     2
#
#    B_losses  B_total_rounds_fought  B_total_title_bouts  \
# 0         2                     11                    0
# 1         5                     24                    0
# 2         5                     38                    0
# 3         1                      3                    0
# 4         3                     19                    0
#
#    B_win_by_Decision_Majority  B_win_by_Decision_Split  \
# 0                           0                        0
# 1                           0                        0
# 2                           0                        2
# 3                           0                        0
# 4                           0                        0
#
#    B_win_by_Decision_Unanimous  B_win_by_KO/TKO  B_win_by_Submission  \
# 0                            1                4                    0
# 1                            0                4                    2
# 2                            6                1                    0
# 3                            0                0                    0
# 4                            4                1                    0
#
#    B_win_by_TKO_Doctor_Stoppage  B_wins  B_Stance  B_Height_cms  B_Reach_cms  \
# 0                             0       5  Orthodox        198.12       208.28
# 1                             0       6  Orthodox        182.88       193.04
# 2                             0       9  Southpaw        185.42       195.58
# 3                             0       0  Orthodox        177.80       177.80
# 4                             0       5  Orthodox        175.26       172.72
#
#    B_Weight_lbs  R_current_lose_streak  R_current_win_streak  R_draw  \
# 0           205                      3                     0       0
# 1           170                      2                     0       0
# 2           185                      1                     0       0
# 3           155                      1                     0       0
# 4           145                      0                     4       0
#
#    R_avg_SIG_STR_landed  R_avg_SIG_STR_pct  R_avg_SUB_ATT  R_avg_TD_landed  \
# 0                  3.95               0.48            0.1             0.61
# 1                  2.97               0.51            0.5             2.27
# 2                  3.77               0.49            1.7             4.48
# 3                  3.79               0.36            0.0             1.57
# 4                  2.64               0.62            0.6             2.85
#
#    R_avg_TD_pct  R_longest_win_streak  R_losses  R_total_rounds_fought  \
# 0          0.36                     4         8                     43
# 1          0.37                     4         8                     44
# 2          0.44                     4         4                     13
# 3          0.35                     2         3                     15
# 4          0.52                     4         0                      8
#
#    R_total_title_bouts  R_win_by_Decision_Majority  R_win_by_Decision_Split  \
# 0                    1                           0                        0
# 1                    0                           0                        1
# 2                    0                           0                        0
# 3                    0                           0                        0
# 4                    0                           0                        0
#
#    R_win_by_Decision_Unanimous  R_win_by_KO/TKO  R_win_by_Submission  \
# 0                            2               11                    0
# 1                            3                4                    3
# 2                            0                1                    5
# 3                            2                2                    0
# 4                            2                0                    2
#
#    R_win_by_TKO_Doctor_Stoppage  R_wins  R_Stance  R_Height_cms  R_Reach_cms  \
# 0                             0      13  Orthodox        187.96       193.04
# 1                             0      11  Orthodox        180.34       193.04
# 2                             0       6  Orthodox        190.50       195.58
# 3                             0       4  Orthodox        175.26       182.88
# 4                             0       4  Orthodox        175.26       177.80
#
#    R_Weight_lbs  R_age  B_age  lose_streak_dif  win_streak_dif  \
# 0           205     37     29               -3               1
# 1           170     33     32                0               0
# 2           205     34     32                0               0
# 3           155     29     32                0               0
# 4           155     28     33                0              -2
#
#    longest_win_streak_dif  win_dif  loss_dif  total_round_dif  \
# 0                       0       -8        -6              -32
# 1                      -2       -5        -3              -20
# 2                       1        3         1               25
# 3                      -2       -4        -2              -12
# 4                      -2        1         3               11
#
#    total_title_bout_dif  ko_dif  sub_dif  height_dif  reach_dif  age_dif  \
# 0                    -1      -7        0       10.16      15.24       -8
# 1                     0       0       -1        2.54       0.00       -1
# 2                     0       0       -5       -5.08       0.00       -2
# 3                     0      -2        0        2.54      -5.08        3
# 4                     0       1       -2        0.00      -5.08        5
#
#    sig_str_dif  avg_sub_att_dif  avg_td_dif  empty_arena  constant_1  \
# 0        -0.53              0.6       -0.37            1           1
# 1         2.19              0.3       -1.48            1           1
# 2        -0.85             -1.6       -3.33            1           1
# 3         0.25              0.0       -1.57            1           1
# 4         2.58             -0.6       -0.31            1           1
#
#    B_match_weightclass_rank  R_match_weightclass_rank  \
# 0                      10.0                       5.0
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    R_Women's Flyweight_rank  R_Women's Featherweight_rank  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#    R_Women's Strawweight_rank  R_Women's Bantamweight_rank  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    R_Heavyweight_rank  R_Light Heavyweight_rank  R_Middleweight_rank  \
# 0                 NaN                       5.0                  NaN
# 1                 NaN                       NaN                  NaN
# 2                 NaN                      13.0                  NaN
# 3                 NaN                       NaN                  NaN
# 4                 NaN                       NaN                  NaN
#
#    R_Welterweight_rank  R_Lightweight_rank  R_Featherweight_rank  \
# 0                  NaN                 NaN                   NaN
# 1                  NaN                 NaN                   NaN
# 2                  NaN                 NaN                   NaN
# 3                  NaN                 NaN                   NaN
# 4                  NaN                 NaN                   NaN
#
#    R_Bantamweight_rank  R_Flyweight_rank  R_Pound-for-Pound_rank  \
# 0                  NaN               NaN                     NaN
# 1                  NaN               NaN                     NaN
# 2                  NaN               NaN                     NaN
# 3                  NaN               NaN                     NaN
# 4                  NaN               NaN                     NaN
#
#    B_Women's Flyweight_rank  B_Women's Featherweight_rank  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#    B_Women's Strawweight_rank  B_Women's Bantamweight_rank  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    B_Heavyweight_rank  B_Light Heavyweight_rank  B_Middleweight_rank  \
# 0                 NaN                      10.0                  NaN
# 1                 NaN                       NaN                  NaN
# 2                 NaN                       NaN                  NaN
# 3                 NaN                       NaN                  NaN
# 4                 NaN                       NaN                  NaN
#
#    B_Welterweight_rank  B_Lightweight_rank  B_Featherweight_rank  \
# 0                  NaN                 NaN                   NaN
# 1                  NaN                 NaN                   NaN
# 2                  NaN                 NaN                   NaN
# 3                  NaN                 NaN                   NaN
# 4                  NaN                 NaN                   NaN
#
#    B_Bantamweight_rank  B_Flyweight_rank  B_Pound-for-Pound_rank better_rank  \
# 0                  NaN               NaN                     NaN         Red
# 1                  NaN               NaN                     NaN     neither
# 2                  NaN               NaN                     NaN     neither
# 3                  NaN               NaN                     NaN     neither
# 4                  NaN               NaN                     NaN     neither
#
#    finish finish_details  finish_round finish_round_time  \
# 0   U-DEC            NaN           5.0              5:00
# 1   U-DEC            NaN           3.0              5:00
# 2   S-DEC            NaN           3.0              5:00
# 3  KO/TKO          Punch           1.0              1:20
# 4   S-DEC            NaN           3.0              5:00
#
#    total_fight_time_secs  r_dec_odds  b_dec_odds  r_sub_odds  b_sub_odds  \
# 0                 1500.0       800.0       900.0      2000.0      1600.0
# 1                  900.0       450.0       350.0       700.0      1100.0
# 2                  900.0       550.0       275.0       275.0      1400.0
# 3                   80.0       175.0       900.0       500.0      3500.0
# 4                  900.0       165.0       200.0       400.0      1200.0
#
#    r_ko_odds  b_ko_odds
# 0     -110.0      175.0
# 1      550.0      120.0
# 2      600.0      185.0
# 3      110.0     1100.0
# 4      900.0      600.0
#             R_odds       B_odds         R_ev         B_ev  no_of_rounds  \
# count  4895.000000  4896.000000  4895.000000  4896.000000   4896.000000
# mean   -117.640449    66.030637    94.827397   167.083323      3.181985
# std     268.881452   247.803928    82.843409   136.944643      0.571515
# min   -1700.000000 -1200.000000     5.882353     8.333333      3.000000
# 25%    -255.000000  -145.000000    39.215686    68.965517      3.000000
# 50%    -150.000000   130.000000    66.666667   130.000000      3.000000
# 75%     126.500000   220.000000   126.500000   220.000000      3.000000
# max     775.000000  1300.000000   775.000000  1300.000000      5.000000
#
#        B_current_lose_streak  B_current_win_streak       B_draw  \
# count            4896.000000           4896.000000  4896.000000
# mean                0.477941              0.875408     0.010621
# std                 0.769386              1.311379     0.108333
# min                 0.000000              0.000000     0.000000
# 25%                 0.000000              0.000000     0.000000
# 50%                 0.000000              0.000000     0.000000
# 75%                 1.000000              1.000000     0.000000
# max                 6.000000             12.000000     2.000000
#
#        B_avg_SIG_STR_landed  B_avg_SIG_STR_pct  B_avg_SUB_ATT  \
# count           3966.000000        4131.000000    4064.000000
# mean              26.308553           0.444741       0.504614
# std               20.935885           0.121332       0.680111
# min                0.000000           0.000000       0.000000
# 25%                5.610000           0.387500       0.000000
# 50%               24.759615           0.450000       0.297059
# 75%               39.075000           0.510000       0.800000
# max              154.000000           1.000000       7.000000
#
#        B_avg_TD_landed  B_avg_TD_pct  B_longest_win_streak     B_losses  \
# count      4063.000000   4054.000000            4896.00000  4896.000000
# mean          1.251173      0.312506               1.76491     1.726511
# std           1.337641      0.249412               1.88258     2.080347
# min           0.000000      0.000000               0.00000     0.000000
# 25%           0.250000      0.106063               0.00000     0.000000
# 50%           1.000000      0.310000               1.00000     1.000000
# 75%           1.846154      0.466979               3.00000     3.000000
# max          10.860000      1.000000              17.00000    15.000000
#
#        B_total_rounds_fought  B_total_title_bouts  B_win_by_Decision_Majority  \
# count            4896.000000          4896.000000                 4896.000000
# mean               10.742443             0.232639                    0.014502
# std                13.056366             1.022727                    0.121255
# min                 0.000000             0.000000                    0.000000
# 25%                 1.000000             0.000000                    0.000000
# 50%                 6.000000             0.000000                    0.000000
# 75%                15.000000             0.000000                    0.000000
# max                97.000000            16.000000                    2.000000
#
#        B_win_by_Decision_Split  B_win_by_Decision_Unanimous  B_win_by_KO/TKO  \
# count              4896.000000                  4896.000000      4896.000000
# mean                  0.260417                     0.975490         0.960989
# std                   0.577227                     1.495861         1.689694
# min                   0.000000                     0.000000         0.000000
# 25%                   0.000000                     0.000000         0.000000
# 50%                   0.000000                     0.000000         0.000000
# 75%                   0.000000                     1.000000         1.000000
# max                   5.000000                    10.000000        20.000000
#
#        B_win_by_Submission  B_win_by_TKO_Doctor_Stoppage       B_wins  \
# count          4896.000000                   4896.000000  4896.000000
# mean              0.588848                      0.029616     2.880923
# std               1.224983                      0.176625     3.608739
# min               0.000000                      0.000000     0.000000
# 25%               0.000000                      0.000000     0.000000
# 50%               0.000000                      0.000000     2.000000
# 75%               1.000000                      0.000000     4.000000
# max              13.000000                      2.000000    31.000000
#
#        B_Height_cms  B_Reach_cms  B_Weight_lbs  R_current_lose_streak  \
# count   4896.000000  4896.000000   4896.000000            4896.000000
# mean     178.084669   182.435958    164.803105               0.613154
# std        8.947115    10.995139     34.362908               0.861302
# min      152.400000     0.000000    115.000000               0.000000
# 25%      172.720000   175.260000    135.000000               0.000000
# 50%      177.800000   182.880000    155.000000               0.000000
# 75%      185.420000   190.500000    185.000000               1.000000
# max      210.820000   213.360000    265.000000               7.000000
#
#        R_current_win_streak       R_draw  R_avg_SIG_STR_landed  \
# count           4896.000000  4896.000000           4441.000000
# mean               1.051062     0.013480             27.396408
# std                1.698478     0.123872             19.871959
# min                0.000000     0.000000              0.000000
# 25%                0.000000     0.000000              8.280000
# 50%                0.000000     0.000000             26.000000
# 75%                1.000000     0.000000             40.090909
# max               16.000000     2.000000            141.000000
#
#        R_avg_SIG_STR_pct  R_avg_SUB_ATT  R_avg_TD_landed  R_avg_TD_pct  \
# count        4539.000000    4539.000000      4539.000000   4529.000000
# mean            0.454709       0.517659         1.337388      0.329411
# std             0.106335       0.651641         1.274270      0.228592
# min             0.000000       0.000000         0.000000      0.000000
# 25%             0.393333       0.000000         0.400000      0.172000
# 50%             0.451538       0.333333         1.000000      0.330000
# 75%             0.511000       0.800000         2.000000      0.466667
# max             1.000000       8.300000        12.500000      1.000000
#
#        R_longest_win_streak     R_losses  R_total_rounds_fought  \
# count           4896.000000  4896.000000            4896.000000
# mean               2.530842     2.393587              15.950980
# std                2.191512     2.488649              16.801419
# min                0.000000     0.000000               0.000000
# 25%                1.000000     1.000000               4.000000
# 50%                2.000000     2.000000              11.000000
# 75%                4.000000     3.000000              23.000000
# max               16.000000    18.000000             448.000000
#
#        R_total_title_bouts  R_win_by_Decision_Majority  \
# count          4896.000000                 4896.000000
# mean              0.552083                    0.025735
# std               1.499930                    0.160920
# min               0.000000                    0.000000
# 25%               0.000000                    0.000000
# 50%               0.000000                    0.000000
# 75%               0.000000                    0.000000
# max              16.000000                    2.000000
#
#        R_win_by_Decision_Split  R_win_by_Decision_Unanimous  R_win_by_KO/TKO  \
# count              4896.000000                  4896.000000      4896.000000
# mean                  0.365809                     1.468750         1.449551
# std                   0.666710                     1.821404         2.074385
# min                   0.000000                     0.000000         0.000000
# 25%                   0.000000                     0.000000         0.000000
# 50%                   0.000000                     1.000000         1.000000
# 75%                   1.000000                     2.000000         2.000000
# max                   5.000000                    10.000000        21.000000
#
#        R_win_by_Submission  R_win_by_TKO_Doctor_Stoppage       R_wins  \
# count          4896.000000                   4896.000000  4896.000000
# mean              0.866422                      0.047386     4.293709
# std               1.495013                      0.229137     4.281123
# min               0.000000                      0.000000     0.000000
# 25%               0.000000                      0.000000     1.000000
# 50%               0.000000                      0.000000     3.000000
# 75%               1.000000                      0.000000     6.000000
# max              14.000000                      2.000000    33.000000
#
#        R_Height_cms  R_Reach_cms  R_Weight_lbs        R_age        B_age  \
# count   4896.000000  4896.000000   4896.000000  4896.000000  4896.000000
# mean     178.030948   182.619835    165.253472    30.056985    29.518382
# std        9.026469    10.879333     34.627769     4.115818     3.982299
# min      152.400000   152.400000    115.000000    19.000000    19.000000
# 25%      170.180000   175.260000    135.000000    27.000000    27.000000
# 50%      177.800000   182.880000    155.000000    30.000000    29.000000
# 75%      185.420000   190.500000    185.000000    33.000000    32.000000
# max      210.820000   214.630000    265.000000    47.000000    47.000000
#
#        lose_streak_dif  win_streak_dif  longest_win_streak_dif      win_dif  \
# count      4896.000000     4896.000000             4896.000000  4896.000000
# mean          0.105392       -0.175449               -0.765931    -1.412786
# std           0.994121        1.729648                2.029394     4.030496
# min          -5.000000      -13.000000              -12.000000   -28.000000
# 25%           0.000000       -1.000000               -2.000000    -3.000000
# 50%           0.000000        0.000000               -1.000000    -1.000000
# 75%           0.000000        0.000000                0.000000     0.000000
# max           6.000000        9.000000               14.000000    23.000000
#
#           loss_dif  total_round_dif  total_title_bout_dif       ko_dif  \
# count  4896.000000      4896.000000           4896.000000  4896.000000
# mean      0.370507        -5.208538             -0.319444    -0.506332
# std       2.873211        16.989572              1.649489     2.084517
# min     -18.000000      -448.000000            -16.000000   -21.000000
# 25%      -1.000000       -12.000000              0.000000    -1.000000
# 50%       0.000000        -3.000000              0.000000     0.000000
# 75%       2.000000         2.000000              0.000000     0.000000
# max      16.000000        80.000000             14.000000    14.000000
#
#            sub_dif   height_dif    reach_dif      age_dif  sig_str_dif  \
# count  4896.000000  4896.000000  4896.000000  4896.000000  4896.000000
# mean     -0.277574     0.018591    -0.251172     0.329044    -3.539160
# std       1.759247     6.963455     9.433336     5.174245    22.521709
# min     -13.000000  -187.960000  -187.960000   -17.000000  -118.000000
# 25%      -1.000000    -5.080000    -5.080000    -3.000000   -14.632937
# 50%       0.000000     0.000000     0.000000     0.000000    -0.750000
# 75%       0.000000     5.080000     5.080000     4.000000     4.741071
# max      10.000000    30.480000    30.480000    17.000000   128.222222
#
#        avg_sub_att_dif   avg_td_dif  empty_arena  constant_1  \
# count      4896.000000  4896.000000  4896.000000      4896.0
# mean         -0.061050    -0.201570     0.138480         1.0
# std           0.848169     1.701414     0.345439         0.0
# min          -8.300000   -11.000000     0.000000         1.0
# 25%          -0.419643    -1.000000     0.000000         1.0
# 50%           0.000000     0.000000     0.000000         1.0
# 75%           0.250000     0.600000     0.000000         1.0
# max           6.000000    10.860000     1.000000         1.0
#
#        B_match_weightclass_rank  R_match_weightclass_rank  \
# count                877.000000               1328.000000
# mean                   8.262258                  6.834337
# std                    4.198510                  4.613596
# min                    1.000000                  0.000000
# 25%                    5.000000                  3.000000
# 50%                    9.000000                  7.000000
# 75%                   12.000000                 11.000000
# max                   15.000000                 15.000000
#
#        R_Women's Flyweight_rank  R_Women's Featherweight_rank  \
# count                 59.000000                           7.0
# mean                   6.677966                           0.0
# std                    4.959980                           0.0
# min                    0.000000                           0.0
# 25%                    2.000000                           0.0
# 50%                    6.000000                           0.0
# 75%                   10.500000                           0.0
# max                   15.000000                           0.0
#
#        R_Women's Strawweight_rank  R_Women's Bantamweight_rank  \
# count                  104.000000                   118.000000
# mean                     6.826923                     7.050847
# std                      4.607807                     4.830189
# min                      0.000000                     0.000000
# 25%                      3.000000                     3.000000
# 50%                      6.500000                     7.000000
# 75%                     10.000000                    11.750000
# max                     15.000000                    15.000000
#
#        R_Heavyweight_rank  R_Light Heavyweight_rank  R_Middleweight_rank  \
# count          142.000000                141.000000           134.000000
# mean             6.774648                  6.673759             7.649254
# std              4.428141                  4.595800             4.637632
# min              0.000000                  0.000000             0.000000
# 25%              3.000000                  3.000000             4.000000
# 50%              6.500000                  6.000000             8.000000
# 75%             10.000000                 10.000000            12.000000
# max             15.000000                 15.000000            15.000000
#
#        R_Welterweight_rank  R_Lightweight_rank  R_Featherweight_rank  \
# count           140.000000          139.000000            133.000000
# mean              6.807143            7.093525              6.827068
# std               4.653298            4.576075              4.571836
# min               0.000000            0.000000              0.000000
# 25%               3.000000            3.000000              3.000000
# 50%               7.000000            6.000000              6.000000
# 75%              11.000000           11.000000             10.000000
# max              15.000000           15.000000             15.000000
#
#        R_Bantamweight_rank  R_Flyweight_rank  R_Pound-for-Pound_rank  \
# count           137.000000        142.000000              166.000000
# mean              6.985401          6.457746                6.789157
# std               4.617717          4.573472                4.147011
# min               0.000000          0.000000                1.000000
# 25%               3.000000          2.000000                3.000000
# 50%               7.000000          7.000000                6.000000
# 75%              11.000000         10.000000               10.000000
# max              15.000000         15.000000               15.000000
#
#        B_Women's Flyweight_rank  B_Women's Featherweight_rank  \
# count                 44.000000                           0.0
# mean                   7.795455                           NaN
# std                    3.950741                           NaN
# min                    1.000000                           NaN
# 25%                    5.000000                           NaN
# 50%                    7.000000                           NaN
# 75%                   10.250000                           NaN
# max                   15.000000                           NaN
#
#        B_Women's Strawweight_rank  B_Women's Bantamweight_rank  \
# count                   61.000000                    78.000000
# mean                     7.803279                     8.192308
# std                      4.269347                     4.378394
# min                      1.000000                     0.000000
# 25%                      4.000000                     5.000000
# 50%                      8.000000                     8.500000
# 75%                     11.000000                    11.750000
# max                     15.000000                    15.000000
#
#        B_Heavyweight_rank  B_Light Heavyweight_rank  B_Middleweight_rank  \
# count          110.000000                 93.000000           102.000000
# mean             8.490909                  8.268817             8.745098
# std              4.072160                  4.225028             4.209104
# min              1.000000                  0.000000             0.000000
# 25%              5.000000                  5.000000             5.000000
# 50%              9.000000                  9.000000             9.000000
# 75%             12.000000                 12.000000            12.000000
# max             15.000000                 15.000000            15.000000
#
#        B_Welterweight_rank  B_Lightweight_rank  B_Featherweight_rank  \
# count            89.000000           87.000000             90.000000
# mean              8.179775            8.126437              8.022222
# std               4.373374            4.119733              4.303063
# min               1.000000            1.000000              0.000000
# 25%               4.000000            5.000000              4.250000
# 50%               8.000000            8.000000              8.500000
# 75%              12.000000           11.500000             11.750000
# max              15.000000           15.000000             15.000000
#
#        B_Bantamweight_rank  B_Flyweight_rank  B_Pound-for-Pound_rank  \
# count            85.000000         95.000000               35.000000
# mean              8.388235          8.473684                9.485714
# std               4.397223          4.259763                4.300283
# min               0.000000          1.000000                2.000000
# 25%               4.000000          5.000000                5.000000
# 50%               9.000000          8.000000               10.000000
# 75%              12.000000         12.000000               13.500000
# max              15.000000         15.000000               15.000000
#
#        finish_round  total_fight_time_secs   r_dec_odds   b_dec_odds  \
# count   4274.000000            4274.000000  4093.000000  4077.000000
# mean       2.408049             652.313758   294.064745   416.544027
# std        0.996643             357.911423   230.583958   306.571299
# min        1.000000               5.000000  -440.000000  -200.000000
# 25%        1.000000             297.000000   167.000000   225.000000
# 50%        3.000000             900.000000   250.000000   349.000000
# 75%        3.000000             900.000000   400.000000   525.000000
# max        5.000000            1500.000000  2200.000000  2600.000000
#
#         r_sub_odds   b_sub_odds    r_ko_odds    b_ko_odds
# count  3847.000000  3835.000000  3847.000000  3834.000000
# mean    843.010138  1064.543155   514.231869   647.257173
# std     550.126761   627.285034   413.622768   458.846643
# min    -370.000000 -1250.000000  -550.000000  -275.000000
# 25%     435.000000   590.000000   240.000000   325.000000
# 50%     720.000000   975.000000   435.000000   548.500000
# 75%    1200.000000  1400.000000   700.000000   880.750000
# max    4665.000000  4785.000000  2675.000000  3200.000000
# (4896, 119)

# %% [markdown]
# Data Cleaning, Preprocessing and Feature Engineering

# %% [markdown]
# From the 1107th row and onwards, 'B_avg_SIG_STR_landed' and 'R_avg_SIG_STR_landed' columns' values are measured per fight and not per minute. Let's solve this inconsistency first.

# %%
id_ = df[(df['R_fighter']=='Henry Cejudo') & 
(df['B_fighter']=='Marlon Moraes')].index.values.astype(int)[0]

# %%
strike_array = np.array(df.iloc[id_]['R_avg_SIG_STR_landed'])
tot_rounds = np.array(df.iloc[id_]['R_total_rounds_fought'])

b_fixed = [] 

count = 0
for item in strike_array:
    new_item = item/(tot_rounds[count]*5)
    b_fixed.append(new_item)
    count+=1

df.iloc[id_]['R_avg_SIG_STR_landed'] = b_fixed

# %%
print(f'Features before transformation:\n\n {df.columns}\n')
df.columns = df.columns.str.strip()
df.rename(columns = lambda x: x.lower(), inplace = True) 
print(f'Features after transformation:\n\n {df.columns}')
# Out:
# Features before transformation:
#
#  Index(['R_fighter', 'B_fighter', 'R_odds', 'B_odds', 'R_ev', 'B_ev', 'date',
#        'location', 'country', 'Winner',
#        ...
#        'finish_details', 'finish_round', 'finish_round_time',
#        'total_fight_time_secs', 'r_dec_odds', 'b_dec_odds', 'r_sub_odds',
#        'b_sub_odds', 'r_ko_odds', 'b_ko_odds'],
#       dtype='object', length=119)
#
# Features after transformation:
#
#  Index(['r_fighter', 'b_fighter', 'r_odds', 'b_odds', 'r_ev', 'b_ev', 'date',
#        'location', 'country', 'winner',
#        ...
#        'finish_details', 'finish_round', 'finish_round_time',
#        'total_fight_time_secs', 'r_dec_odds', 'b_dec_odds', 'r_sub_odds',
#        'b_sub_odds', 'r_ko_odds', 'b_ko_odds'],
#       dtype='object', length=119)

# %%
for f in df.columns:
    if df[f].dtype == 'O':
        df[f] = df[f].str.strip()
        print(f'The unique values for {f} variable: {df[f].unique()}\n')
# Out:
# The unique values for r_fighter variable: ['Thiago Santos' 'Alex Oliveira' 'Misha Cirkunov' ... 'Caol Uno'
#  'Eliot Marshall' 'Eric Schafer']
#
# The unique values for b_fighter variable: ['Johnny Walker' 'Niko Price' 'Krzysztof Jotko' ... 'James Irvin'
#  'Shannon Gugerty' 'Chase Gormley']
#
# The unique values for date variable: ['2021-10-02' '2021-09-25' '2021-09-18' '2021-09-04' '2021-08-28'
#  '8/21/2021' '8/7/2021' '7/31/2021' '7/24/2021' '7/17/2021' '7/10/2021'
#  '6/26/2021' '6/19/2021' '6/12/2021' '6/5/2021' '5/22/2021' '5/15/2021'
#  '5/8/2021' '5/1/2021' '4/24/2021' '4/17/2021' '4/10/2021' '3/27/2021'
#  '3/20/2021' '3/13/2021' '3/6/2021' '2/27/2021' '2/20/2021' '2/13/2021'
#  '2/6/2021' '1/23/2021' '1/20/2021' '1/16/2021' '12/19/2020' '12/12/2020'
#  '12/5/2020' '11/28/2020' '11/21/2020' '11/14/2020' '11/7/2020'
#  '10/31/2020' '10/24/2020' '10/17/2020' '10/10/2020' '10/3/2020'
#  '9/26/2020' '9/19/2020' '9/12/2020' '9/5/2020' '8/29/2020' '8/22/2020'
#  '8/15/2020' '8/8/2020' '8/1/2020' '7/25/2020' '7/18/2020' '7/15/2020'
#  '7/11/2020' '6/27/2020' '6/20/2020' '6/13/2020' '6/6/2020' '5/30/2020'
#  '5/16/2020' '5/13/2020' '5/9/2020' '3/14/2020' '3/7/2020' '2/29/2020'
#  '2/22/2020' '6/29/2019' '6/22/2019' '7/6/2019' '2/15/2020' '7/13/2019'
#  '7/20/2019' '7/27/2019' '8/3/2019' '2/8/2020' '8/10/2019' '8/17/2019'
#  '8/31/2019' '9/7/2019' '9/14/2019' '9/21/2019' '9/28/2019' '10/5/2019'
#  '1/25/2020' '10/12/2019' '10/18/2019' '10/26/2019' '1/18/2020'
#  '11/2/2019' '11/9/2019' '11/16/2019' '12/21/2019' '12/14/2019'
#  '12/7/2019' '6/8/2019' '6/1/2019' '5/18/2019' '5/11/2019' '5/4/2019'
#  '4/27/2019' '4/20/2019' '4/13/2019' '3/30/2019' '3/23/2019' '3/16/2019'
#  '3/9/2019' '3/2/2019' '2/23/2019' '2/17/2019' '2/9/2019' '2/2/2019'
#  '1/19/2019' '12/29/2018' '12/15/2018' '12/8/2018' '12/1/2018'
#  '11/30/2018' '11/24/2018' '11/17/2018' '11/10/2018' '11/3/2018'
#  '10/27/2018' '10/6/2018' '9/22/2018' '9/15/2018' '9/8/2018' '8/25/2018'
#  '8/4/2018' '7/28/2018' '7/22/2018' '7/14/2018' '7/7/2018' '7/6/2018'
#  '6/23/2018' '6/9/2018' '6/1/2018' '5/27/2018' '5/19/2018' '5/12/2018'
#  '4/21/2018' '4/14/2018' '4/7/2018' '3/17/2018' '3/3/2018' '2/24/2018'
#  '2/18/2018' '2/10/2018' '2/3/2018' '1/27/2018' '1/20/2018' '1/14/2018'
#  '12/30/2017' '12/16/2017' '12/9/2017' '12/2/2017' '12/1/2017'
#  '11/25/2017' '11/18/2017' '11/11/2017' '11/4/2017' '10/28/2017'
#  '10/21/2017' '10/7/2017' '9/22/2017' '9/16/2017' '9/9/2017' '9/2/2017'
#  '8/5/2017' '7/29/2017' '7/22/2017' '7/16/2017' '7/8/2017' '7/7/2017'
#  '6/25/2017' '6/17/2017' '6/10/2017' '6/3/2017' '5/28/2017' '5/13/2017'
#  '4/22/2017' '4/15/2017' '4/8/2017' '3/18/2017' '3/11/2017' '3/4/2017'
#  '2/19/2017' '2/11/2017' '2/4/2017' '1/28/2017' '1/15/2017' '12/30/2016'
#  '12/17/2016' '12/10/2016' '12/9/2016' '12/3/2016' '11/26/2016'
#  '11/19/2016' '11/12/2016' '11/5/2016' '10/8/2016' '10/1/2016' '9/24/2016'
#  '9/17/2016' '9/10/2016' '9/3/2016' '8/27/2016' '8/20/2016' '8/6/2016'
#  '7/30/2016' '7/23/2016' '7/13/2016' '7/9/2016' '7/8/2016' '7/7/2016'
#  '6/18/2016' '6/4/2016' '5/29/2016' '5/14/2016' '5/8/2016' '4/23/2016'
#  '4/16/2016' '4/10/2016' '3/19/2016' '3/5/2016' '2/27/2016' '2/21/2016'
#  '2/6/2016' '1/30/2016' '1/17/2016' '1/2/2016' '12/19/2015' '12/12/2015'
#  '12/11/2015' '12/10/2015' '11/28/2015' '11/21/2015' '11/14/2015'
#  '11/7/2015' '10/24/2015' '10/3/2015' '9/26/2015' '9/5/2015' '8/23/2015'
#  '8/8/2015' '8/1/2015' '7/25/2015' '7/18/2015' '7/15/2015' '7/12/2015'
#  '7/11/2015' '6/27/2015' '6/20/2015' '6/13/2015' '6/6/2015' '5/30/2015'
#  '5/23/2015' '5/16/2015' '5/9/2015' '4/25/2015' '4/18/2015' '4/11/2015'
#  '4/4/2015' '3/21/2015' '3/14/2015' '2/28/2015' '2/22/2015' '2/14/2015'
#  '1/31/2015' '1/24/2015' '1/18/2015' '1/3/2015' '12/20/2014' '12/13/2014'
#  '12/12/2014' '12/6/2014' '11/22/2014' '11/15/2014' '11/8/2014'
#  '11/7/2014' '10/25/2014' '10/4/2014' '9/27/2014' '9/20/2014' '9/13/2014'
#  '9/5/2014' '8/30/2014' '8/23/2014' '8/16/2014' '7/26/2014' '7/19/2014'
#  '7/16/2014' '7/6/2014' '7/5/2014' '6/28/2014' '6/14/2014' '6/7/2014'
#  '5/31/2014' '5/24/2014' '5/10/2014' '4/26/2014' '4/19/2014' '4/16/2014'
#  '4/11/2014' '3/23/2014' '3/15/2014' '3/8/2014' '3/1/2014' '2/22/2014'
#  '2/15/2014' '2/1/2014' '1/25/2014' '1/15/2014' '1/4/2014' '12/28/2013'
#  '12/14/2013' '12/6/2013' '11/30/2013' '11/16/2013' '11/9/2013'
#  '11/6/2013' '10/26/2013' '10/19/2013' '10/9/2013' '9/21/2013' '9/4/2013'
#  '8/31/2013' '8/28/2013' '8/17/2013' '8/3/2013' '7/27/2013' '7/6/2013'
#  '6/15/2013' '6/8/2013' '5/25/2013' '5/18/2013' '4/27/2013' '4/20/2013'
#  '4/13/2013' '4/6/2013' '3/16/2013' '3/2/2013' '2/23/2013' '2/16/2013'
#  '2/2/2013' '1/26/2013' '1/19/2013' '12/29/2012' '12/15/2012' '12/14/2012'
#  '12/8/2012' '11/17/2012' '11/10/2012' '10/13/2012' '10/5/2012'
#  '9/29/2012' '9/22/2012' '8/11/2012' '8/4/2012' '7/21/2012' '7/11/2012'
#  '7/7/2012' '6/23/2012' '6/22/2012' '6/8/2012' '6/1/2012' '5/26/2012'
#  '5/15/2012' '5/5/2012' '4/21/2012' '4/14/2012' '3/2/2012' '2/25/2012'
#  '2/15/2012' '2/4/2012' '1/28/2012' '1/20/2012' '1/14/2012' '12/30/2011'
#  '12/10/2011' '12/3/2011' '11/19/2011' '11/12/2011' '11/5/2011'
#  '10/29/2011' '10/8/2011' '10/1/2011' '9/24/2011' '9/17/2011' '8/27/2011'
#  '8/14/2011' '8/6/2011' '7/2/2011' '6/26/2011' '6/11/2011' '6/4/2011'
#  '5/28/2011' '4/30/2011' '3/26/2011' '3/19/2011' '3/3/2011' '2/26/2011'
#  '2/5/2011' '1/22/2011' '1/1/2011' '12/11/2010' '12/4/2010' '11/20/2010'
#  '11/13/2010' '10/23/2010' '10/16/2010' '9/25/2010' '9/15/2010'
#  '8/28/2010' '8/7/2010' '8/1/2010' '7/3/2010' '6/19/2010' '6/12/2010'
#  '5/29/2010' '5/8/2010' '4/10/2010' '3/31/2010' '3/27/2010' '3/21/2010']
#
# The unique values for location variable: ['Las Vegas, Nevada, USA' 'Houston, Texas, USA' 'Glendale, Arizona, USA'
#  'Jacksonville, Florida, USA' 'Abu Dhabi, Abu Dhabi, United Arab Emirates'
#  'Brasilia, Distrito Federal, Brazil' 'Norfolk, Virginia, USA'
#  'Auckland, New Zealand' 'Minneapolis, Minnesota, USA'
#  'Greenville, South Carolina, USA' 'Rio Rancho, New Mexico, USA'
#  'Sacramento, California, USA' 'San Antonio, Texas, USA'
#  'Edmonton, Alberta, Canada' 'Newark, New Jersey, USA'
#  'Montevideo, Uruguay' 'Anaheim, California, USA'
#  'Shenzhen, Guangdong, China' 'Vancouver, British Columbia, Canada'
#  'Mexico City, Distrito Federal, Mexico' 'Copenhagen, Denmark'
#  'Melbourne, Victoria, Australia' 'Raleigh, North Carolina, USA'
#  'Tampa, Florida, USA' 'Boston, Massachusetts, USA' 'Kallang, Singapore'
#  'New York City, New York, USA' 'Moscow, Moscow, Russia'
#  'Sao Paulo, Sao Paulo, Brazil' 'Busan, South Korea' 'Washington, DC, USA'
#  'Chicago, Illinois, USA' 'Stockholm, Sweden' 'Rochester, New York, USA'
#  'Rio de Janeiro, Rio de Janeiro, Brazil' 'Ottawa, Ontario, Canada'
#  'Sunrise, Florida, USA' 'Saint Petersburg, Saint Petersburg, Russia'
#  'Atlanta, Georgia, USA' 'Philadelphia, Pennsylvania, USA'
#  'Nashville, Tennessee, USA' 'London, England, United Kingdom'
#  'Wichita, Kansas, USA' 'Prague, Czech Republic' 'Phoenix, Arizona, USA'
#  'Fortaleza, Ceara, Brazil' 'Brooklyn, New York, USA'
#  'Los Angeles, California, USA' 'Milwaukee, Wisconsin, USA'
#  'Toronto, Ontario, Canada' 'Adelaide, South Australia, Australia'
#  'Beijing, China' 'Buenos Aires, Buenos Aires, Argentina'
#  'Denver, Colorado, USA' 'Moncton, New Brunswick, Canada'
#  'Dallas, Texas, USA' 'Lincoln, Nebraska, USA' 'Calgary, Alberta, Canada'
#  'Hamburg, Hamburg, Germany' 'Boise, Idaho, USA' 'Utica, New York, USA'
#  'Liverpool, England, United Kingdom' 'Santiago, Chile'
#  'Atlantic City, New Jersey, USA' 'Orlando, Florida, USA'
#  'Austin, Texas, USA' 'Perth, Western Australia, Australia'
#  'Belem, Para, Brazil' 'Charlotte, North Carolina, USA'
#  'St. Louis, Missouri, USA' 'Winnipeg, Manitoba, Canada'
#  'Fresno, California, USA' 'Detroit, Michigan, USA'
#  'Shanghai, Hebei, China' 'Sydney, New South Wales, Australia'
#  'Gdansk, Poland' 'Saitama, Saitama, Japan'
#  'Pittsburgh, Pennsylvania, USA' 'Rotterdam, Zuid-Holland, Netherlands'
#  'Uniondale, New York, USA' 'Glasgow, Scotland, United Kingdom'
#  'Oklahoma City, Oklahoma, USA' 'Kansas City, Missouri, USA'
#  'Buffalo, New York, USA' 'Halifax, Nova Scotia, Canada'
#  'Albany, New York, USA' 'Belfast, Northern Ireland, United Kingdom'
#  'Manchester, England, United Kingdom' 'Portland, Oregon, USA'
#  'Hidalgo, Texas, USA' 'Cleveland, Ohio, USA' 'Salt Lake City, Utah, USA'
#  'Sioux Falls, South Dakota, USA' 'Curitiba, Parana, Brazil'
#  'Zagreb, Croatia' 'Brisbane, Queensland, Australia' 'Seoul, South Korea'
#  'Monterrey, Nuevo Leon, Mexico' 'Dublin, Leinster, Ireland'
#  'Saitama, Japan' 'Saskatoon, Saskatchewan, Canada'
#  'San Diego, California, USA' 'Hollywood, Florida, USA'
#  'Berlin, Berlin, Germany' 'New Orleans, Louisiana, USA'
#  'Goiania, Goias, Brazil' 'Manila, Philippines' 'Montreal, Quebec, Canada'
#  'Krakow, Poland' 'Fairfax, Virginia, USA' 'Rio de Janeiro, Brazil'
#  'Porto Alegre, Rio Grande do Sul, Brazil' 'Broomfield, Colorado, USA'
#  'Barueri, Sao Paulo, Brazil' 'Uberlandia, Minas Gerais, Brazil'
#  'Ledyard, Connecticut, USA' 'Tulsa, Oklahoma, USA' 'Macau, China'
#  'Bangor, Maine, USA' 'San Jose, California, USA'
#  'Albuquerque, New Mexico, USA' 'Sao Paulo, Brazil' 'Berlin, Germany'
#  'Cincinnati, Ohio, USA' 'Baltimore, Maryland, USA'
#  'Quebec City, Quebec, Canada' 'Abu Dhabi, United Arab Emirates'
#  'Natal, Rio Grande do Norte, Brazil'
#  'Jaragua do Sul, Santa Catarina, Brazil' 'Duluth, Georgia, USA'
#  'Singapore, Singapore' 'Fort Campbell, Kentucky, USA'
#  'Belo Horizonte, Minas Gerais, Brazil' 'Indianapolis, Indiana, USA'
#  'Seattle, Washington, USA' 'Gold Coast, Queensland, Australia'
#  'Nottingham, England, United Kingdom' 'East Rutherford, New Jersey, USA'
#  'Omaha, Nebraska, USA' 'Birmingham, England, United Kingdom'
#  'Louisville, Kentucky, USA' 'Killeen, Texas, USA'
#  'Auburn Hills, Michigan, USA'
#  'Oberhausen, North Rhine-Westphalia, Germany' 'Oakland, California, USA']
#
# The unique values for country variable: ['USA' 'United Arab Emirates' 'Brazil' 'New Zealand' 'Canada' 'Uruguay'
#  'China' 'Mexico' 'Denmark' 'Australia' 'Singapore' 'Russia' 'South Korea'
#  'Sweden' 'United Kingdom' 'Czech Republic' 'Argentina' 'Germany' 'Chile'
#  'Poland' 'Japan' 'Netherlands' 'Croatia' 'Ireland' 'Philippines']
#
# The unique values for winner variable: ['Red' 'Blue']
#
# The unique values for weight_class variable: ['Light Heavyweight' 'Welterweight' 'Middleweight' 'Lightweight'
#  "Women's Flyweight" "Women's Bantamweight" 'Bantamweight' 'Featherweight'
#  'Heavyweight' 'Catch Weight' 'Flyweight' "Women's Strawweight"
#  "Women's Featherweight"]
#
# The unique values for gender variable: ['MALE' 'FEMALE']
#
# The unique values for b_stance variable: ['Orthodox' 'Southpaw' 'Switch' nan 'Open Stance']
#
# The unique values for r_stance variable: ['Orthodox' 'Southpaw' 'Switch' 'Open Stance']
#
# The unique values for better_rank variable: ['Red' 'neither' 'Blue']
#
# The unique values for finish variable: ['U-DEC' 'S-DEC' 'KO/TKO' 'SUB' 'M-DEC' 'DQ' nan 'Overturned']
#
# The unique values for finish_details variable: [nan 'Punch' 'Punches' 'Elbow' 'Armbar' 'Rear Naked Choke' 'Kick'
#  "D'Arce Choke" 'Elbows' 'Heel Hook' 'Guillotine Choke' 'Flying Knee'
#  'Kimura' 'Knee' 'Triangle Choke' 'Kneebar' 'Anaconda Choke'
#  'Arm Triangle' 'Knees' 'Ankle Lock' 'Neck Crank' 'Peruvian Necktie'
#  'Spinning Back Fist' 'Other - Choke' 'Other - Lock' 'Slam'
#  'Spinning Back Kick' 'Omoplata' 'North-South Choke' 'Injury' 'Kicks'
#  'Keylock']
#
# The unique values for finish_round_time variable: ['5:00' '1:20' '4:47' '2:51' '2:04' '2:22' '4:13' '4:00' '0:44' '4:54'
#  '4:25' '1:23' '4:01' '0:15' '3:31' '3:47' '2:09' '2:10' '2:26' '4:35'
#  '2:38' '4:17' '2:13' '2:30' '2:56' '1:44' '2:15' '3:12' '1:49' '0:17'
#  '3:04' '1:53' '4:39' '1:46' '3:58' '4:55' '2:33' '4:11' '3:25' '4:32'
#  '4:44' '1:16' '2:35' '1:00' '1:08' '1:50' '4:21' '3:48' '2:11' '3:09'
#  '2:57' '3:45' '3:49' '1:05' '1:54' '3:40' '0:35' '1:29' '1:07' '4:33'
#  '1:41' '2:02' '2:31' '4:34' '0:20' '0:30' '0:56' '4:19' '1:37' '4:45'
#  '3:02' '0:37' '2:54' '1:59' '0:07' '4:59' '4:06' '4:27' '3:00' nan '1:33'
#  '3:38' '1:47' '0:26' '4:29' '4:56' '0:57' '2:06' '1:30' '2:48' '0:45'
#  '2:36' '4:48' '1:18' '1:28' '4:15' '2:25' '4:42' '1:12' '4:18' '2:43'
#  '2:29' '3:24' '2:21' '0:49' '3:15' '3:44' '2:53' '2:41' '2:44' '0:48'
#  '4:50' '4:36' '0:41' '2:42' '0:22' '0:32' '0:59' '1:14' '1:10' '3:26'
#  '1:51' '3:18' '3:03' '0:18' '0:39' '3:36' '2:05' '1:04' '0:25' '3:37'
#  '3:39' '4:58' '2:49' '0:28' '2:34' '2:58' '3:01' '0:38' '1:38' '1:25'
#  '3:21' '0:40' '1:11' '3:19' '0:42' '0:58' '0:09' '4:10' '0:05' '1:39'
#  '3:08' '4:02' '0:16' '0:46' '3:07' '3:54' '0:12' '2:39' '4:09' '0:36'
#  '1:03' '4:31' '4:26' '1:09' '4:14' '3:33' '1:55' '4:43' '1:31' '1:36'
#  '1:56' '0:27' '2:46' '3:14' '3:57' '1:06' '2:01' '3:17' '2:32' '1:43'
#  '4:38' '2:47' '2:07' '2:27' '0:29' '2:03' '2:50' '1:26' '1:22' '3:43'
#  '4:51' '4:57' '0:33' '4:20' '0:47' '2:17' '3:52' '4:49' '0:50' '3:16'
#  '2:12' '3:10' '2:52' '4:24' '3:05' '2:37' '1:17' '1:58' '4:41' '3:34'
#  '3:20' '4:52' '1:34' '3:27' '1:01' '3:53' '3:59' '0:53' '0:55' '0:54'
#  '2:28' '3:56' '4:12' '1:32' '1:40' '2:19' '1:15' '2:59' '4:05' '0:43'
#  '1:19' '2:14' '3:41' '1:57' '1:02' '4:46' '2:40' '0:14' '3:42' '3:22'
#  '4:03' '1:21' '3:46' '1:27' '4:53' '3:13' '2:00' '0:52' '3:32' '3:28'
#  '4:40' '2:18' '2:55' '4:16' '2:23' '1:45' '4:28' '2:16' '1:35' '4:23'
#  '1:48' '3:50' '2:24' '2:45' '1:42' '4:30' '1:24' '2:08' '4:08' '0:24'
#  '3:30' '4:22' '4:37' '3:51' '0:21' '3:35' '0:34' '4:07' '0:19' '1:52'
#  '1:13' '0:13' '3:11' '4:04' '0:23' '3:06' '0:51' '0:08' '0:31' '2:20'
#  '3:23' '0:11' '3:55']

# %%
df.duplicated().sum() # No duplicate rows
# Out:
# 0

# %%
sns.heatmap(data = df.isna(), yticklabels = False, cbar = False, cmap = plt.cm.magma)
plt.title(label = 'Heatmap for Missing Values', fontsize = 16, color='red')
plt.xlabel(xlabel = 'Features', fontsize = 16, color='red')
plt.show()

# %%
''' Missing values in percentage
'''
for column in df.columns:
    n_missing = df[column].isnull().sum()
    ratio = n_missing / df.shape[0]
    if ratio!=0:
        print(f'For column {column}: {ratio:.2%}')
# Out:
# For column r_odds: 0.02%
# For column r_ev: 0.02%
# For column b_avg_sig_str_landed: 19.00%
# For column b_avg_sig_str_pct: 15.62%
# For column b_avg_sub_att: 16.99%
# For column b_avg_td_landed: 17.01%
# For column b_avg_td_pct: 17.20%
# For column b_stance: 0.04%
# For column r_avg_sig_str_landed: 9.29%
# For column r_avg_sig_str_pct: 7.29%
# For column r_avg_sub_att: 7.29%
# For column r_avg_td_landed: 7.29%
# For column r_avg_td_pct: 7.50%
# For column b_match_weightclass_rank: 82.09%
# For column r_match_weightclass_rank: 72.88%
# For column r_women's flyweight_rank: 98.79%
# For column r_women's featherweight_rank: 99.86%
# For column r_women's strawweight_rank: 97.88%
# For column r_women's bantamweight_rank: 97.59%
# For column r_heavyweight_rank: 97.10%
# For column r_light heavyweight_rank: 97.12%
# For column r_middleweight_rank: 97.26%
# For column r_welterweight_rank: 97.14%
# For column r_lightweight_rank: 97.16%
# For column r_featherweight_rank: 97.28%
# For column r_bantamweight_rank: 97.20%
# For column r_flyweight_rank: 97.10%
# For column r_pound-for-pound_rank: 96.61%
# For column b_women's flyweight_rank: 99.10%
# For column b_women's featherweight_rank: 100.00%
# For column b_women's strawweight_rank: 98.75%
# For column b_women's bantamweight_rank: 98.41%
# For column b_heavyweight_rank: 97.75%
# For column b_light heavyweight_rank: 98.10%
# For column b_middleweight_rank: 97.92%
# For column b_welterweight_rank: 98.18%
# For column b_lightweight_rank: 98.22%
# For column b_featherweight_rank: 98.16%
# For column b_bantamweight_rank: 98.26%
# For column b_flyweight_rank: 98.06%
# For column b_pound-for-pound_rank: 99.29%
# For column finish: 4.86%
# For column finish_details: 57.07%
# For column finish_round: 12.70%
# For column finish_round_time: 12.70%
# For column total_fight_time_secs: 12.70%
# For column r_dec_odds: 16.40%
# For column b_dec_odds: 16.73%
# For column r_sub_odds: 21.43%
# For column b_sub_odds: 21.67%
# For column r_ko_odds: 21.43%
# For column b_ko_odds: 21.69%

# %%
'''Dropping the columns with 
null values higher than 30% 
'''
for column in df.columns:
    n_missing = df[column].isnull().sum()
    ratio = n_missing / df.shape[0]
    if ratio>0.3:
        df.drop(column, axis=1, inplace=True)
print(f'Number of features now: {df.shape[1]}')
# Out:
# Number of features now: 90

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df_numeric = df[[f for f in df.columns if df[f].dtype =='float64' or df[f].dtype =='int64']]
df_categoric = df[[f for f in df.columns if df[f].dtype =='O' and f!='r_fighter' and f!='b_fighter']]
df_d = df['date']
rf_bf = df[['r_fighter', 'b_fighter']]

# %%
display(df_numeric.head(), df_categoric.head())
# Out:
#    r_odds  b_odds        r_ev        b_ev  no_of_rounds  \
# 0  -150.0     130   66.666667  130.000000             5
# 1   170.0    -200  170.000000   50.000000             3
# 2   110.0    -130  110.000000   76.923077             3
# 3  -675.0     475   14.814815  475.000000             3
# 4  -135.0     115   74.074074  115.000000             3
#
#    b_current_lose_streak  b_current_win_streak  b_draw  b_avg_sig_str_landed  \
# 0                      0                     1       0                  3.42
# 1                      2                     0       0                  5.16
# 2                      1                     0       0                  2.92
# 3                      1                     0       0                  4.04
# 4                      0                     2       0                  5.22
#
#    b_avg_sig_str_pct  b_avg_sub_att  b_avg_td_landed  b_avg_td_pct  \
# 0               0.59            0.7             0.24          1.00
# 1               0.42            0.8             0.79          0.22
# 2               0.41            0.1             1.15          0.34
# 3               0.34            0.0             0.00          0.00
# 4               0.56            0.0             2.54          0.39
#
#    b_longest_win_streak  b_losses  b_total_rounds_fought  b_total_title_bouts  \
# 0                     4         2                     11                    0
# 1                     2         5                     24                    0
# 2                     5         5                     38                    0
# 3                     0         1                      3                    0
# 4                     2         3                     19                    0
#
#    b_win_by_decision_majority  b_win_by_decision_split  \
# 0                           0                        0
# 1                           0                        0
# 2                           0                        2
# 3                           0                        0
# 4                           0                        0
#
#    b_win_by_decision_unanimous  b_win_by_ko/tko  b_win_by_submission  \
# 0                            1                4                    0
# 1                            0                4                    2
# 2                            6                1                    0
# 3                            0                0                    0
# 4                            4                1                    0
#
#    b_win_by_tko_doctor_stoppage  b_wins  b_height_cms  b_reach_cms  \
# 0                             0       5        198.12       208.28
# 1                             0       6        182.88       193.04
# 2                             0       9        185.42       195.58
# 3                             0       0        177.80       177.80
# 4                             0       5        175.26       172.72
#
#    b_weight_lbs  r_current_lose_streak  r_current_win_streak  r_draw  \
# 0           205                      3                     0       0
# 1           170                      2                     0       0
# 2           185                      1                     0       0
# 3           155                      1                     0       0
# 4           145                      0                     4       0
#
#    r_avg_sig_str_landed  r_avg_sig_str_pct  r_avg_sub_att  r_avg_td_landed  \
# 0                  3.95               0.48            0.1             0.61
# 1                  2.97               0.51            0.5             2.27
# 2                  3.77               0.49            1.7             4.48
# 3                  3.79               0.36            0.0             1.57
# 4                  2.64               0.62            0.6             2.85
#
#    r_avg_td_pct  r_longest_win_streak  r_losses  r_total_rounds_fought  \
# 0          0.36                     4         8                     43
# 1          0.37                     4         8                     44
# 2          0.44                     4         4                     13
# 3          0.35                     2         3                     15
# 4          0.52                     4         0                      8
#
#    r_total_title_bouts  r_win_by_decision_majority  r_win_by_decision_split  \
# 0                    1                           0                        0
# 1                    0                           0                        1
# 2                    0                           0                        0
# 3                    0                           0                        0
# 4                    0                           0                        0
#
#    r_win_by_decision_unanimous  r_win_by_ko/tko  r_win_by_submission  \
# 0                            2               11                    0
# 1                            3                4                    3
# 2                            0                1                    5
# 3                            2                2                    0
# 4                            2                0                    2
#
#    r_win_by_tko_doctor_stoppage  r_wins  r_height_cms  r_reach_cms  \
# 0                             0      13        187.96       193.04
# 1                             0      11        180.34       193.04
# 2                             0       6        190.50       195.58
# 3                             0       4        175.26       182.88
# 4                             0       4        175.26       177.80
#
#    r_weight_lbs  r_age  b_age  lose_streak_dif  win_streak_dif  \
# 0           205     37     29               -3               1
# 1           170     33     32                0               0
# 2           205     34     32                0               0
# 3           155     29     32                0               0
# 4           155     28     33                0              -2
#
#    longest_win_streak_dif  win_dif  loss_dif  total_round_dif  \
# 0                       0       -8        -6              -32
# 1                      -2       -5        -3              -20
# 2                       1        3         1               25
# 3                      -2       -4        -2              -12
# 4                      -2        1         3               11
#
#    total_title_bout_dif  ko_dif  sub_dif  height_dif  reach_dif  age_dif  \
# 0                    -1      -7        0       10.16      15.24       -8
# 1                     0       0       -1        2.54       0.00       -1
# 2                     0       0       -5       -5.08       0.00       -2
# 3                     0      -2        0        2.54      -5.08        3
# 4                     0       1       -2        0.00      -5.08        5
#
#    sig_str_dif  avg_sub_att_dif  avg_td_dif  empty_arena  constant_1  \
# 0        -0.53              0.6       -0.37            1           1
# 1         2.19              0.3       -1.48            1           1
# 2        -0.85             -1.6       -3.33            1           1
# 3         0.25              0.0       -1.57            1           1
# 4         2.58             -0.6       -0.31            1           1
#
#    b_match_weightclass_rank  r_match_weightclass_rank  \
# 0                      10.0                       5.0
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    r_women's flyweight_rank  r_women's featherweight_rank  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#    r_women's strawweight_rank  r_women's bantamweight_rank  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    r_heavyweight_rank  r_light heavyweight_rank  r_middleweight_rank  \
# 0                 NaN                       5.0                  NaN
# 1                 NaN                       NaN                  NaN
# 2                 NaN                      13.0                  NaN
# 3                 NaN                       NaN                  NaN
# 4                 NaN                       NaN                  NaN
#
#    r_welterweight_rank  r_lightweight_rank  r_featherweight_rank  \
# 0                  NaN                 NaN                   NaN
# 1                  NaN                 NaN                   NaN
# 2                  NaN                 NaN                   NaN
# 3                  NaN                 NaN                   NaN
# 4                  NaN                 NaN                   NaN
#
#    r_bantamweight_rank  r_flyweight_rank  r_pound-for-pound_rank  \
# 0                  NaN               NaN                     NaN
# 1                  NaN               NaN                     NaN
# 2                  NaN               NaN                     NaN
# 3                  NaN               NaN                     NaN
# 4                  NaN               NaN                     NaN
#
#    b_women's flyweight_rank  b_women's featherweight_rank  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#    b_women's strawweight_rank  b_women's bantamweight_rank  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#    b_heavyweight_rank  b_light heavyweight_rank  b_middleweight_rank  \
# 0                 NaN                      10.0                  NaN
# 1                 NaN                       NaN                  NaN
# 2                 NaN                       NaN                  NaN
# 3                 NaN                       NaN                  NaN
# 4                 NaN                       NaN                  NaN
#
#    b_welterweight_rank  b_lightweight_rank  b_featherweight_rank  \
# 0                  NaN                 NaN                   NaN
# 1                  NaN                 NaN                   NaN
# 2                  NaN                 NaN                   NaN
# 3                  NaN                 NaN                   NaN
# 4                  NaN                 NaN                   NaN
#
#    b_bantamweight_rank  b_flyweight_rank  b_pound-for-pound_rank  \
# 0                  NaN               NaN                     NaN
# 1                  NaN               NaN                     NaN
# 2                  NaN               NaN                     NaN
# 3                  NaN               NaN                     NaN
# 4                  NaN               NaN                     NaN
#
#    finish_round  total_fight_time_secs  r_dec_odds  b_dec_odds  r_sub_odds  \
# 0           5.0                 1500.0       800.0       900.0      2000.0
# 1           3.0                  900.0       450.0       350.0       700.0
# 2           3.0                  900.0       550.0       275.0       275.0
# 3           1.0                   80.0       175.0       900.0       500.0
# 4           3.0                  900.0       165.0       200.0       400.0
#
#    b_sub_odds  r_ko_odds  b_ko_odds
# 0      1600.0     -110.0      175.0
# 1      1100.0      550.0      120.0
# 2      1400.0      600.0      185.0
# 3      3500.0      110.0     1100.0
# 4      1200.0      900.0      600.0
#                  location country winner       weight_class gender  b_stance  \
# 0  Las Vegas, Nevada, USA     USA    Red  Light Heavyweight   MALE  Orthodox
# 1  Las Vegas, Nevada, USA     USA   Blue       Welterweight   MALE  Orthodox
# 2  Las Vegas, Nevada, USA     USA   Blue       Middleweight   MALE  Southpaw
# 3  Las Vegas, Nevada, USA     USA    Red        Lightweight   MALE  Orthodox
# 4  Las Vegas, Nevada, USA     USA   Blue        Lightweight   MALE  Orthodox
#
#    r_stance better_rank  finish finish_details finish_round_time
# 0  Orthodox         Red   U-DEC            NaN              5:00
# 1  Orthodox     neither   U-DEC            NaN              5:00
# 2  Orthodox     neither   S-DEC            NaN              5:00
# 3  Orthodox     neither  KO/TKO          Punch              1:20
# 4  Orthodox     neither   S-DEC            NaN              5:00

# %%
for f in df_categoric.columns:
    le = LabelEncoder()
    df_categoric[f] = le.fit_transform(df_categoric[f])

# %%
for f in df_numeric.columns:
    df_numeric[f].fillna(value=df_numeric[f].mean(), inplace=True)

# %%
df = pd.concat([df_numeric, df_categoric], axis=1)

# %%
'''Visual recheck of the
missing values'''
sns.heatmap(data = df.isna(), yticklabels = False, cbar = False, cmap = plt.cm.magma)
plt.title(label = 'Heatmap for Missing Values', fontsize = 16, color='red')
plt.xlabel(xlabel = 'Features', fontsize = 16, color='red')
plt.show()

# %% [markdown]
# A number of columns in the dataset are post-fight features which won't be necessary while predicting. Let's filter out some unnecessary variables.

# %%
'''
Let's keep the most significant features
'''
insig_feat = ['gender',  'location', 'country',  'empty_arena', 
              'constant_1', 'no_of_rounds', 'b_reach_cms', 'r_reach_cms', 
              'total_round_dif',  'finish_round_time', 'finish', 
              
              
              'b_draw', 'b_total_rounds_fought', 
              'b_win_by_tko_doctor_stoppage', 'b_weight_lbs',
              'b_match_weightclass_rank', 'b_women\'s flyweight_rank', 'b_women\'s featherweight_rank',
              'b_women\'s strawweight_rank', 'b_women\'s bantamweight_rank', 'b_heavyweight_rank',
              'b_light heavyweight_rank', 'b_welterweight_rank', 'b_flyweight_rank',
              'b_pound-for-pound_rank', 'r_ev', 'b_ev',
              
               'r_draw', 'r_total_rounds_fought', 
              'r_win_by_tko_doctor_stoppage', 'r_weight_lbs', 
              'r_match_weightclass_rank', 'r_women\'s flyweight_rank', 'r_women\'s featherweight_rank',
              'r_women\'s strawweight_rank', 'r_women\'s bantamweight_rank', 'r_heavyweight_rank',
              'r_light heavyweight_rank', 'r_welterweight_rank', 'r_flyweight_rank',
              'r_pound-for-pound_rank', 'finish_details',  'finish_round', 
              'r_dec_odds', 'b_dec_odds', 'r_sub_odds', 'b_sub_odds', 'r_ko_odds', 'b_ko_odds', 
              'b_win_by_decision_majority', 'r_win_by_decision_majority', 'total_fight_time_secs',
              'b_featherweight_rank', 'b_bantamweight_rank', 'b_lightweight_rank', 'b_middleweight_rank',
              'r_middleweight_rank', 'r_lightweight_rank', 'r_featherweight_rank', 'r_bantamweight_rank', 
             ]

# %%
'b_current_lose_streak', 'r_current_lose_streak', 'lose_streak_dif', 'total_title_bout_dif',
'r_avg_sig_str_pct', 'b_avg_sig_str_pct', 'r_avg_td_pct', 'b_avg_td_pct', 'b_total_title_bouts',
'r_total_title_bouts',
# Out:
# ('r_total_title_bouts',)

# %%
df.drop(labels = insig_feat, axis=1, inplace=True)

# %%
print(f'Remaining features: {df.iloc[:,:-1].shape[1]}')
# Out:
# Remaining features: 54

# %%
df['loss_dif'] = abs(df['b_losses']-df['r_losses'])
df['win_dec_dif'] = abs(df['b_win_by_decision_split']-df['r_win_by_decision_split'])
df['win_dec_una'] = abs(df['b_win_by_decision_unanimous']-df['r_win_by_decision_unanimous'])
df['win_tko'] = abs(df['b_win_by_ko/tko']-df['r_win_by_ko/tko'])
df['win_sub'] = abs(df['b_win_by_submission']-df['r_win_by_submission'])

# %%
'''Converting American odds 
to decimal odds'''

df['r_odds'] = df['r_odds'].apply(lambda x: round(x/100+1,2) if x>0 else round(100/abs(x)+1,2))
df['b_odds'] = df['b_odds'].apply(lambda x: round(x/100+1,2) if x>0 else round(100/abs(x)+1,2))

# %%
df[['r_odds', 'b_odds']].head()
# Out:
#    r_odds  b_odds
# 0    1.67    2.30
# 1    2.70    1.50
# 2    2.10    1.77
# 3    1.15    5.75
# 4    1.74    2.15

# %%
for f in df.columns:
    if df[f].dtype!='O' and df[f].dtype!='datetime64[ns]':
        df[f] = abs(df[f])

# %%
# Drop columns from which the new ones are engineered
df.drop(['weight_class', 'b_stance', 'r_stance', 'b_win_by_decision_split',
        'b_win_by_decision_unanimous', 'b_win_by_ko/tko',
        'b_win_by_submission', 'r_win_by_decision_split',
        'r_win_by_decision_unanimous', 'r_win_by_ko/tko',
        'r_win_by_submission'], axis=1, inplace=True)

# %%
# Our data consists of the followings
df.drop(['win_streak_dif', 'longest_win_streak_dif', 'win_dif',
'loss_dif', 'ko_dif', 'sub_dif', 'height_dif', 'age_dif', 
'sig_str_dif', 'avg_sub_att_dif', 'avg_td_dif', 'win_dec_dif',
'win_dec_una', 'win_tko', 'win_sub', 'reach_dif',
'lose_streak_dif', 'total_title_bout_dif'
], axis=1, inplace=True)

# %%
SOME_NUMERIC_FEATURES = [f for f in df.columns if df[f].dtype=='int64' or df[f].dtype=='float64'
                        and f!='winner' and f!='better_rank']
print(f'The total number of rows that contain outliers before: {df.loc[(abs(zscore(df[SOME_NUMERIC_FEATURES])) > 3).any(axis = 1)].shape[0]}')
# Out:
# The total number of rows that contain outliers before: 1818

# %%
# Coercing outliers via IQR

def impute_outliers(value):
    if value > upperlimit:
        value = upperlimit
    elif value < lowerlimit:
        value = lowerlimit
    return value

for feature in SOME_NUMERIC_FEATURES:
    Q3 = df[feature].quantile(q = 0.75)
    Q1 = df[feature].quantile(q = 0.25)
    IQR = Q3 - Q1
    outlier_range = IQR * 1.7
    upperlimit = Q3 + outlier_range
    lowerlimit = Q1 - outlier_range
    df[feature] = df[feature].apply(impute_outliers)
    
while df.loc[(abs(zscore(df[SOME_NUMERIC_FEATURES])) > 3).any(axis = 1)].shape[0] != 0:
    df.drop(index = df.loc[(abs(zscore(df[SOME_NUMERIC_FEATURES])) > 3).any(axis = 1)].index, inplace = True)    
print(f'The total number of rows that contain outliers now: {df.loc[(abs(zscore(df[SOME_NUMERIC_FEATURES])) > 3).any(axis = 1)].shape[0]}')
# Out:
# The total number of rows that contain outliers now: 0

# %%
# The data which's prepared for modelling
df.head(10)
# Out:
#    r_odds  b_odds  b_current_lose_streak  b_current_win_streak  \
# 0    1.67    2.30                      0                     1
# 1    2.70    1.50                      2                     0
# 2    2.10    1.77                      1                     0
# 3    1.15    5.75                      1                     0
# 4    1.74    2.15                      0                     2
# 5    3.15    1.38                      0                     2
# 6    6.00    1.14                      0                     3
# 7    1.65    2.35                      0                     1
# 8    1.36    3.25                      1                     0
# 9    1.65    2.35                      2                     0
#
#    b_avg_sig_str_landed  b_avg_sig_str_pct  b_avg_sub_att  b_avg_td_landed  \
# 0                  3.42               0.59            0.7             0.24
# 1                  5.16               0.42            0.8             0.79
# 2                  2.92               0.41            0.1             1.15
# 3                  4.04               0.34            0.0             0.00
# 4                  5.22               0.56            0.0             2.54
# 5                  5.48               0.56            1.4             3.83
# 6                  7.88               0.54            0.0             1.50
# 7                  3.03               0.40            0.4             3.50
# 8                  0.99               0.55            0.0             0.00
# 9                  3.04               0.53            1.0             0.00
#
#    b_avg_td_pct  b_longest_win_streak  b_losses  b_total_title_bouts  \
# 0          1.00                     4         2                    0
# 1          0.22                     2         5                    0
# 2          0.34                     5         5                    0
# 3          0.00                     0         1                    0
# 4          0.39                     2         3                    0
# 5          0.50                     2         0                    0
# 6          0.50                     3         0                    0
# 7          0.32                     1         2                    0
# 8          0.00                     0         1                    0
# 9          0.00                     0         2                    0
#
#    b_win_by_decision_split  b_win_by_decision_unanimous  b_win_by_ko/tko  \
# 0                        0                            1                4
# 1                        0                            0                4
# 2                        2                            6                1
# 3                        0                            0                0
# 4                        0                            4                1
# 5                        0                            0                1
# 6                        1                            2                0
# 7                        0                            0                1
# 8                        0                            0                0
# 9                        0                            0                0
#
#    b_win_by_submission  b_wins  b_height_cms  r_current_lose_streak  \
# 0                    0       5        198.12                      3
# 1                    2       6        182.88                      2
# 2                    0       9        185.42                      1
# 3                    0       0        177.80                      1
# 4                    0       5        175.26                      0
# 5                    1       2        167.64                      1
# 6                    0       3        165.10                      1
# 7                    0       1        182.88                      0
# 8                    0       0        170.18                      1
# 9                    0       0        170.18                      1
#
#    r_current_win_streak  r_avg_sig_str_landed  r_avg_sig_str_pct  \
# 0                     0                  3.95               0.48
# 1                     0                  2.97               0.51
# 2                     0                  3.77               0.49
# 3                     0                  3.79               0.36
# 4                     4                  2.64               0.62
# 5                     0                  3.89               0.56
# 6                     0                  4.37               0.43
# 7                     1                  5.10               0.52
# 8                     0                  3.79               0.38
# 9                     0                  1.74               0.52
#
#    r_avg_sub_att  r_avg_td_landed  r_avg_td_pct  r_longest_win_streak  \
# 0            0.1             0.61          0.36                     4
# 1            0.5             2.27          0.37                     4
# 2            1.7             4.48          0.44                     4
# 3            0.0             1.57          0.35                     2
# 4            0.6             2.85          0.52                     4
# 5            0.5             0.51          0.50                     2
# 6            0.0             0.39          0.18                     3
# 7            0.5             0.53          1.00                     3
# 8            0.0             0.69          0.50                     2
# 9            0.0             2.01          0.30                     0
#
#    r_losses  r_total_title_bouts  r_win_by_decision_split  \
# 0         8                    1                        0
# 1         8                    0                        1
# 2         4                    0                        0
# 3         3                    0                        0
# 4         0                    0                        0
# 5         3                    0                        0
# 6         5                    1                        2
# 7         1                    0                        0
# 8         4                    0                        0
# 9         1                    0                        0
#
#    r_win_by_decision_unanimous  r_win_by_ko/tko  r_win_by_submission  r_wins  \
# 0                            2               11                    0      13
# 1                            3                4                    3      11
# 2                            0                1                    5       6
# 3                            2                2                    0       4
# 4                            2                0                    2       4
# 5                            1                2                    1       4
# 6                            2                1                    0       5
# 7                            0                4                    0       4
# 8                            3                1                    0       4
# 9                            0                0                    0       0
#
#    r_height_cms  r_age  b_age  winner  better_rank
# 0        187.96     37     29       1            1
# 1        180.34     33     32       0            2
# 2        190.50     34     32       0            2
# 3        175.26     29     32       1            2
# 4        175.26     28     33       0            2
# 5        172.72     36     23       0            2
# 6        165.10     38     26       0            0
# 7        175.26     28     27       0            2
# 8        170.18     36     29       1            2
# 9        167.64     33     30       1            2

# %%
'''Scaling numeric features. Robust Scaler 
was the one with the highest result'''

scaler = RobustScaler()
df.iloc[:,:-1] = scaler.fit_transform(df.iloc[:,:-1])   
df = pd.DataFrame(df)

# %%
# Our target variable isn't imbalanced. Thus, oversampling wouldn't significantly raise our results.
plt.subplot(1, 2, 2)
sns.countplot(x = 'winner', data = df)
plt.title(label = 'Imbalance check for the target variable', fontsize = 16, color='r')
plt.xlabel(xlabel = 'Classes', fontsize = 16, color='r')
plt.ylabel(ylabel = 'Count', fontsize = 16, color='r')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Modelling: Logistic Regression (LR)

# %%
X = df.drop('winner', axis=1)
y = df['winner']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=43, test_size=0.05,
                                                   stratify=y)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((4651, 37), (4651,), (245, 37), (245,))

# %%
log_reg = LogisticRegression(max_iter=1000)
log_model = log_reg.fit(X_train, y_train)

# %%
y_pred = log_reg.predict(X_test)

# %%
log_reg.score(X_train,y_train)
# Out:
# 0.6581380348312191

# %%
log_reg.score(X_test,y_test)
# Out:
# 0.673469387755102

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.62      0.54      0.58       102
#          0.0       0.70      0.77      0.73       143
#
#     accuracy                           0.67       245
#    macro avg       0.66      0.65      0.66       245
# weighted avg       0.67      0.67      0.67       245

# %%
plot_confusion_matrix(log_model, X_test, y_test)
plt.show()

# %%
model = RandomForestClassifier(n_estimators=200, oob_score=True, random_state=43)

# %%
r_model = model.fit(X_train, y_train)

# %%
pred = model.predict(X_test)

# %%
model.oob_score_
# Out:
# 0.6368522898301441

# %%
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.66      0.56      0.60       102
#          0.0       0.72      0.79      0.75       143
#
#     accuracy                           0.69       245
#    macro avg       0.69      0.67      0.68       245
# weighted avg       0.69      0.69      0.69       245
